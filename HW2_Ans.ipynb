# %% [markdown]
# # Homework 2
# ### Jagannathan Chengavalli Lakshminarayanan - 305834859
# ### Nanditha Raja - 305831258
# ---------------------------------------------------------------------------------------------------

# %%
# The following line will import KNeighborsClassifier "Class"
# KNeighborsClassifier is name of a "sklearn class" to perform "KNN Classification" 

from sklearn.neighbors import KNeighborsClassifier

# %%
# Importing the required packages and libraries
# we will need numpy and pandas later
import numpy as np
import pandas as pd

# %%
# reading a CSV file directly from Web, and store it in a pandas DataFrame:
# "read_csv" is a pandas function to read csv files from web or local device:

iris_df = pd.read_csv('https://raw.githubusercontent.com/mpourhoma/CS4661/master/iris.csv')

# %%
# checking the dataset by printing every 10 lines:
iris_df[0::10]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 40            5.0          3.5           1.3          0.3      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 70            5.9          3.2           4.8          1.8  versicolor
# 80            5.5          2.4           3.8          1.1  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# ...

# %%
# Creating the Feature Matrix for iris dataset:

# create a python list of feature names that would like to pick from the dataset:
feature_cols = ['sepal_length','sepal_width','petal_length','petal_width']

# use the above list to select the features from the original DataFrame
X = iris_df[feature_cols]  

# print the first 5 rows
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 8             4.4          2.9           1.4          0.2
# 9             4.9          3.1           1.5          0.1
# 10            5.4          3.7           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 12            4.8          3.0           1.4          0.1
# 13            4.3          3.0           1.1          0.1
# 14            5.8          4.0           1.2          0.2
# ...

# %%
y = iris_df['species'] # this is the original categorical labels (the latest revision of sklearn accepts non-numerical labels)

# checking the label vector by printing every 10 values
y[::10]
# Out:
# 0          setosa
# 10         setosa
# 20         setosa
# 30         setosa
# 40         setosa
# 50     versicolor
# 60     versicolor
# 70     versicolor
# 80     versicolor
# 90     versicolor
# 100     virginica
# 110     virginica
# 120     virginica
# 130     virginica
# 140     virginica
# Name: species, dtype: object

# %%
# Randomly splitting the original dataset into training set and testing set
# The function"train_test_split" from "sklearn.cross_validation" library performs random splitting.
# "test_size=0.4" means that pick 40% of data samples for testing set, and the rest (60%) for training set.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
# Instantiating another "object" of KNeighborsClassifier "class" with k=3:

k = 3
my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k) # name of the object is arbitrary!

# %%
# We use the method "fit" of the object along with training dataset and labels to train the model.

my_knn_for_HW2.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
# Training ONLY on the training set:

my_knn_for_HW2.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
# Testing on the testing set:

y_predict = my_knn_for_HW2.predict(X_test)

print(y_predict)
# Out:
# ['setosa' 'versicolor' 'versicolor' 'setosa' 'virginica' 'versicolor'
#  'virginica' 'setosa' 'setosa' 'virginica' 'versicolor' 'setosa'
#  'virginica' 'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor'
#  'setosa' 'setosa' 'versicolor' 'versicolor' 'versicolor' 'setosa'
#  'virginica' 'versicolor' 'setosa' 'setosa' 'versicolor' 'virginica'
#  'versicolor' 'virginica' 'versicolor' 'virginica' 'virginica' 'setosa'
#  'versicolor' 'setosa' 'versicolor' 'virginica' 'virginica' 'setosa'
#  'versicolor' 'virginica' 'versicolor' 'virginica' 'setosa' 'setosa'
#  'setosa' 'versicolor' 'setosa' 'setosa' 'virginica' 'virginica'
#  'virginica' 'virginica' 'virginica' 'versicolor' 'virginica' 'versicolor']

# %%
# Function "accuracy_score" from "sklearn.metrics" will perform element-to-element comparision and returns the 
# percent of correct predictions:

from sklearn.metrics import accuracy_score

# Example:
y_pred    = [0, 2, 1, 1]
y_actual  = [0, 1, 2, 1]

score = accuracy_score(y_actual, y_pred)

print(score)
# Out:
# 0.5

# %%
# We can now compare the "predicted labels" for the Testing Set with its "actual labels" to evaluate the accuracy 
# Function "accuracy_score" from "sklearn.metrics" will perform the element-to-element comparision and returns the 
# portion of correct predictions:

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_predict)

print(accuracy)
# Out:
# 0.983333333333

# %%
from sklearn.metrics import accuracy_score

k_list = [1,5,7,15,28,60]
accuracies = []
for ks in k_list:
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=ks)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_predict))

print("Accuracies for K=1,5,7,15,28,60 respectively \n ",accuracies) 

# Does the accuracy always get better by increasing K? 
# Not really, it is tough to assume the rite K for at most accuracy
# Out:
# Accuracies for K=1,5,7,15,28,60 respectively
#   [0.96666666666666667, 0.98333333333333328, 0.98333333333333328, 0.98333333333333328, 0.94999999999999996, 0.80000000000000004]

# %%
from sklearn.model_selection import train_test_split

features_list = ['sepal_length','sepal_width','petal_length','petal_width']
accuracies = []

for feature in features_list:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracies.append(accuracy_score(y_test, y_predict))

print("Accuracies for K=3,sepal_length,sepal_width,petal_length,petal_width respectively \n ",accuracies)

# Which one is the first best feature? -- petal_length
# Which one is the second best feature? -- petal_width
# Out:
# Accuracies for K=3,sepal_length,sepal_width,petal_length,petal_width respectively
#   [0.6333333333333333, 0.53333333333333333, 0.96666666666666667, 0.93333333333333335]

# %%
feature_pair1 = ['sepal_length','sepal_width']
feature_pair2 = ['sepal_length','petal_length']
feature_pair3 = ['sepal_length','petal_width']
feature_pair4 = ['sepal_width','petal_length']
feature_pair5 = ['sepal_width','petal_width']
feature_pair6 = ['petal_length','petal_width']

for feature in feature_pair1:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy1 = accuracy_score(y_test, y_predict)

for feature in feature_pair2:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy2 = accuracy_score(y_test, y_predict)

for feature in feature_pair3:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy3 = accuracy_score(y_test, y_predict)

for feature in feature_pair4:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy4 = accuracy_score(y_test, y_predict)

for feature in feature_pair5:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy5 = accuracy_score(y_test, y_predict)

for feature in feature_pair6:
    X = iris_df[[feature]]
    y = iris_df['species']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)
    my_knn_for_HW2 = KNeighborsClassifier(n_neighbors=k)
    my_knn_for_HW2.fit(X, y)
    my_knn_for_HW2.fit(X_train, y_train)
    y_predict = my_knn_for_HW2.predict(X_test)
    accuracy6 = accuracy_score(y_test, y_predict)
       
print("feature_pair1 = 'sepal_length','sepal_width'", accuracy1)
print("feature_pair2 = 'sepal_length','petal_length'", accuracy2)
print("feature_pair3 = 'sepal_length','petal_width'", accuracy3)
print("feature_pair4 = 'sepal_width','petal_length'", accuracy4)
print("feature_pair5 = 'sepal_width','petal_width'", accuracy5)
print("feature_pair6 = 'petal_length','petal_width'", accuracy6)


# Which “feature pair” provide the best accuracy? -- 'sepal_length','petal_length'  & 'sepal_width','petal_length'
# Big Question: Does the “best feature pair” from part (f) contain of both “first best feature” and “second	best feature” from part	(e)?
# In other word, can we conclude that the “best two features” for classification are the 
# “first best individual feature” and the “second best individual feature” together?

# The first and second best feature here did not form the best feature pair, instead one of the best feature
# namely 'petal_length' which is the first best feature is a part of both feature pairs.

# The best feautres by themselves might help in predicting the testing dataset but a combination of the best features
# may not contribute much in predicting the labels and thus end up being less accurate
# Out:
# feature_pair1 = 'sepal_length','sepal_width' 0.533333333333
# feature_pair2 = 'sepal_length','petal_length' 0.966666666667
# feature_pair3 = 'sepal_length','petal_width' 0.933333333333
# feature_pair4 = 'sepal_width','petal_length' 0.966666666667
# feature_pair5 = 'sepal_width','petal_width' 0.933333333333
# feature_pair6 = 'petal_length','petal_width' 0.933333333333
